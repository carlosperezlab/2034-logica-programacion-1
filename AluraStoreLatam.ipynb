# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosperezlab/2034-logica-programacion-1/blob/ProyectoInicial/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ###En este punto lo que se nos solicita es calcular el ingreso total de cada tienda, para despues llevar estos datos un gráfico que nos permita comparar de manera más fácil a ellas.

# %%
def ingresosTienda(dataset):
  return dataset['Precio'].sum()

# %%
#Para tienda 1
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %%
tienda4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB

# %% [markdown]
# ##Para Tienda 1

# %%
ingresoTienda1 = ingresosTienda(tienda)
ingresoTienda1= int(ingresoTienda1)
print(ingresoTienda1)
# Out:
# 1150880400

# %% [markdown]
# ##Para Tienda 2

# %%
ingresoTienda2 = ingresosTienda(tienda2)
ingresoTienda2= int(ingresoTienda2)
print(ingresoTienda2)
# Out:
# 1116343500

# %% [markdown]
# ##Para Tienda 3

# %%
ingresoTienda3 = ingresosTienda(tienda3)
ingresoTienda3= int(ingresoTienda3)
print(ingresoTienda3)
# Out:
# 1098019600

# %% [markdown]
# ##Para Tienda 4

# %%
ingresoTienda4 = ingresosTienda(tienda4)
ingresoTienda4= int(ingresoTienda4)
print(ingresoTienda4)
# Out:
# 1038375700

# %% [markdown]
# ##Comparación

# %%
ingresos_totales = {
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Ingreso Total': [ingresoTienda1, ingresoTienda2, ingresoTienda3, ingresoTienda4]
}

df_ingresos = pd.DataFrame(ingresos_totales)
display(df_ingresos)
# Out:
#      Tienda  Ingreso Total
# 0  Tienda 1     1150880400
# 1  Tienda 2     1116343500
# 2  Tienda 3     1098019600
# 3  Tienda 4     1038375700

# %%
import matplotlib.pyplot as plt

df_ingresos.plot(x='Tienda', y='Ingreso Total', kind='bar', color='blue')
# Out:
# <Axes: xlabel='Tienda'>

# %% [markdown]
# ## Con respecto a los ingresos totales de cada tienda, la Tienda 1 es la que mas ingresos tiene, con $1.150.880.400

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# ##En este punto lo que se nos solicita es calcular el ingreso total de cada tienda, pero esta vez para cada categoria de producto vendido.

# %%
VentaPorCategoriaTienda1 = tienda.groupby('Categoría del Producto')['Producto'].count().reset_index(name='Cantidad').sort_values(by='Cantidad', ascending=False)

print(VentaPorCategoriaTienda1)
# Out:
#     Categoría del Producto  Cantidad
# 7                  Muebles       465
# 3             Electrónicos       448
# 5                 Juguetes       324
# 2        Electrodomésticos       312
# 1     Deportes y diversión       284
# 4   Instrumentos musicales       182
# 6                   Libros       173
# 0  Artículos para el hogar       171

# %%
VentaPorCategoriaTienda2 = tienda2.groupby('Categoría del Producto')['Producto'].count().reset_index(name='Cantidad').sort_values(by='Cantidad', ascending=False)

print(VentaPorCategoriaTienda2)
# Out:
#     Categoría del Producto  Cantidad
# 7                  Muebles       442
# 3             Electrónicos       422
# 5                 Juguetes       313
# 2        Electrodomésticos       305
# 1     Deportes y diversión       275
# 4   Instrumentos musicales       224
# 6                   Libros       197
# 0  Artículos para el hogar       181

# %%
VentaPorCategoriaTienda3 = tienda3.groupby('Categoría del Producto')['Producto'].count().reset_index(name='Cantidad').sort_values(by='Cantidad', ascending=False)

print(VentaPorCategoriaTienda3)
# Out:
#     Categoría del Producto  Cantidad
# 7                  Muebles       499
# 3             Electrónicos       451
# 5                 Juguetes       315
# 2        Electrodomésticos       278
# 1     Deportes y diversión       277
# 6                   Libros       185
# 0  Artículos para el hogar       177
# 4   Instrumentos musicales       177

# %%
VentaPorCategoriaTienda4 = tienda4.groupby('Categoría del Producto')['Producto'].count().reset_index(name='Cantidad').sort_values(by='Cantidad', ascending=False)

print(VentaPorCategoriaTienda4)
# Out:
#     Categoría del Producto  Cantidad
# 7                  Muebles       480
# 3             Electrónicos       451
# 5                 Juguetes       338
# 1     Deportes y diversión       277
# 2        Electrodomésticos       254
# 0  Artículos para el hogar       201
# 6                   Libros       187
# 4   Instrumentos musicales       170

# %% [markdown]
# ##Ahora graficaremos las ventas totales por categoria para todas las tiendas en conjunto

# %%
VentasPorCategoriaTotal = pd.concat([VentaPorCategoriaTienda1, VentaPorCategoriaTienda2, VentaPorCategoriaTienda3, VentaPorCategoriaTienda4]).groupby('Categoría del Producto')['Cantidad'].sum().reset_index(name='Cantidad').sort_values(by='Cantidad', ascending=False)

print(VentasPorCategoriaTotal)
plt.figure(figsize=(10, 6))
plt.pie(VentasPorCategoriaTotal['Cantidad'], labels=VentasPorCategoriaTotal['Categoría del Producto'], autopct='%1.1f%%', startangle=140)
# Out:
#     Categoría del Producto  Cantidad
# 7                  Muebles      1886
# 3             Electrónicos      1772
# 5                 Juguetes      1290
# 2        Electrodomésticos      1149
# 1     Deportes y diversión      1113
# 4   Instrumentos musicales       753
# 6                   Libros       742
# 0  Artículos para el hogar       730
# ([<matplotlib.patches.Wedge at 0x7eecb4a511c0>,
# ...
#  [Text(-1.0972948560391327, 0.07709733400098358, 'Muebles'),
#   Text(-0.45147720559528887, -1.003079424984816, 'Electrónicos'),
#   Text(0.6180446468868105, -0.9099564904183924, 'Juguetes'),
#   Text(1.0855891317264876, -0.1774717923427012, 'Electrodomésticos'),
#   Text(0.9133382498820507, 0.613036084828938, 'Deportes y diversión'),
#   Text(0.385785222389318, 1.0301309441940014, 'Instrumentos musicales'),
#   Text(-0.1529091585403176, 1.0893203336183954, 'Libros'),
#   Text(-0.6476984814639832, 0.8890931768432656, 'Artículos para el hogar')],
# ...

# %% [markdown]
# ##Observando el gráfico pódemos ver que la categoria que mas se vende es muebles con el 20% del total de las ventas.

# %% [markdown]
# # 3. Calificación promedio de la tienda
# ##En este punto evaluaremos a las tiendas de acuerdo con las calificaciones que dejaron los clientes.

# %%
PromedioTienda1 = tienda['Calificación'].mean()
print(f"Tienda 1: {PromedioTienda1:.3f}")
# Out:
# Tienda 1: 3.977

# %%
PromedioTienda2 = tienda2['Calificación'].mean()
print(f"Tienda 2: {PromedioTienda2:.3f}")
# Out:
# Tienda 2: 4.037

# %%
PromedioTienda3 = tienda3['Calificación'].mean()
print(f"Tienda 3: {PromedioTienda3:.3f}")
# Out:
# Tienda 3: 4.048

# %%
PromedioTienda4 = tienda4['Calificación'].mean()
print(f"Tienda 4: {PromedioTienda4:.3f}")
# Out:
# Tienda 4: 3.996

# %%
import matplotlib.pyplot as plt

promedio =[PromedioTienda1, PromedioTienda2, PromedioTienda3, PromedioTienda4]
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
data  = {'Tienda': tiendas, 'Promedio': promedio}
df = pd.DataFrame(data)
print(df)
# Out:
#      Tienda  Promedio
# 0  Tienda 1  3.976685
# 1  Tienda 2  4.037304
# 2  Tienda 3  4.048326
# 3  Tienda 4  3.995759

# %%
plt.plot(tiendas, promedio)
plt.title('Promedio de Calificación por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Promedio de Calificación')
plt.grid(True)

plt.show()

# %% [markdown]
# #***La tienda mejor valorada por los clientes es la Tienda 3***
#
# ---
#
#
#
# ---

# %% [markdown]
# # 4.*Productos* más y menos vendidos
#
# ## En este punto, debemos identificar qué productos fueron los más vendidos y los menos vendidos en cada tienda. Visualizando los resultados para que quede claro qué productos destacaron en ventas en cada tienda.

# %%
#Definimos las funciones
#esta funcion arroja los tres productos mas vendidos y sus respectivas cantidades

def productos_mas_vendidos(dataset):
  return dataset.groupby('Producto').size().reset_index(name ='Cantidad Vendida').sort_values(by='Cantidad Vendida', ascending=False).head(3)

#Esta funcion arroja los tres productos menos vendidos y sus respectivas cantidades

def productos_menos_vendidos(dataset):
  return dataset.groupby('Producto').size().reset_index(name = 'Cantidad Vendida').sort_values(by='Cantidad Vendida', ascending=True).head(3)

# %% [markdown]
# #Para la Tienda 1

# %% [markdown]
# ###Productos mas vendidos

# %%
productos_mas_vendidos(tienda)
# Out:
#          Producto  Cantidad Vendida
# 1         Armario                60
# 48  TV LED UHD 4K                60
# 33     Microondas                60

# %% [markdown]
# ###Productos menos vendidos

# %%
productos_menos_vendidos(tienda)
# Out:
#                      Producto  Cantidad Vendida
# 4   Auriculares con micrófono                33
# 13               Celular ABXY                33
# 37            Olla de presión                35

# %% [markdown]
# #Para la Tienda 2

# %% [markdown]
# ###Productos mas vendidos

# %%
productos_mas_vendidos(tienda2)
# Out:
#                      Producto  Cantidad Vendida
# 24  Iniciando en programación                65
# 33                 Microondas                62
# 7                     Batería                61

# %% [markdown]
# ###Productos menos vendidos

# %%
productos_menos_vendidos(tienda2)
# Out:
#            Producto  Cantidad Vendida
# 26    Juego de mesa                32
# 23        Impresora                34
# 31  Mesa de comedor                34

# %% [markdown]
# #Para la Tienda 3

# %% [markdown]
# ###Productos mas vendidos

# %%
productos_mas_vendidos(tienda3)
# Out:
#            Producto  Cantidad Vendida
# 27    Kit de bancas                57
# 31  Mesa de comedor                56
# 11        Cama king                56

# %% [markdown]
# ###Productos menos vendidos

# %%
productos_menos_vendidos(tienda3)
# Out:
#                    Producto  Cantidad Vendida
# 9   Bloques de construcción                35
# 42             Set de vasos                36
# 34                  Mochila                36

# %% [markdown]
# #Para la Tienda 4

# %% [markdown]
# ###Productos mas vendidos

# %%
productos_menos_vendidos(tienda4)
# Out:
#               Producto  Cantidad Vendida
# 22  Guitarra eléctrica                33
# 1              Armario                34
# 21   Guitarra acústica                37

# %% [markdown]
# ###Productos menos vendidos

# %%
productos_menos_vendidos(tienda4)
# Out:
#               Producto  Cantidad Vendida
# 22  Guitarra eléctrica                33
# 1              Armario                34
# 21   Guitarra acústica                37

# %% [markdown]
# #Visualización gráfica

# %%
import numpy as np

def get_product_sales_data(df, store_name):
    ventas = df.groupby('Producto')['Producto'].count().sort_values(ascending=False)
    mas_vendido_name = ventas.idxmax()
    mas_vendido_count = ventas.max()
    menos_vendido_name = ventas.idxmin()
    menos_vendido_count = ventas.min()
    return {
        'Store': store_name,
        'Producto': [mas_vendido_name, menos_vendido_name],
        'Cantidad': [mas_vendido_count, menos_vendido_count],
        'Tipo': ['Más Vendido', 'Menos Vendido']
    }

tienda1_df = pd.read_csv(url)

data_tienda1 = get_product_sales_data(tienda1_df, 'Tienda 1')
data_tienda2 = get_product_sales_data(tienda2, 'Tienda 2')
data_tienda3 = get_product_sales_data(tienda3, 'Tienda 3')
data_tienda4 = get_product_sales_data(tienda4, 'Tienda 4')


combined_data = pd.concat([
    pd.DataFrame(data_tienda1),
    pd.DataFrame(data_tienda2),
    pd.DataFrame(data_tienda3),
    pd.DataFrame(data_tienda4)
]).reset_index(drop=True)


fig, ax = plt.subplots(figsize=(14, 5))

stores = combined_data['Store'].unique()
product_types = combined_data['Tipo'].unique()

width = 0.35
ind = np.arange(len(stores))


mas_vendido_counts = [combined_data[(combined_data['Store'] == s) & (combined_data['Tipo'] == 'Más Vendido')]['Cantidad'].iloc[0] for s in stores]
rects1 = ax.bar(ind - width/2, mas_vendido_counts, width, label='Más Vendido', color='skyblue')

menos_vendido_counts = [combined_data[(combined_data['Store'] == s) & (combined_data['Tipo'] == 'Menos Vendido')]['Cantidad'].iloc[0] for s in stores]
rects2 = ax.bar(ind + width/2, menos_vendido_counts, width, label='Menos Vendido', color='lightcoral')


for i, store in enumerate(stores):
    mas_vendido_product = combined_data[(combined_data['Store'] == store) & (combined_data['Tipo'] == 'Más Vendido')]['Producto'].iloc[0]
    menos_vendido_product = combined_data[(combined_data['Store'] == store) & (combined_data['Tipo'] == 'Menos Vendido')]['Producto'].iloc[0]

    ax.text(ind[i] - width/2, mas_vendido_counts[i] + 1, f'{mas_vendido_counts[i]}', ha='center', va='bottom', fontsize=9, color='black')
    ax.text(ind[i] + width/2, menos_vendido_counts[i] + 1, f'{menos_vendido_counts[i]}', ha='center', va='bottom', fontsize=9, color='black')


    ax.text(ind[i] - width/2, mas_vendido_counts[i] - 10, f'{mas_vendido_product}', ha='center', va='top', fontsize=8, color='darkblue', rotation=45)
    ax.text(ind[i] + width/2, menos_vendido_counts[i] - 10, f'{menos_vendido_product}', ha='center', va='top', fontsize=8, color='darkred', rotation=45)


ax.set_ylabel('Cantidad de Ventas')
ax.set_title('Productos Más y Menos Vendidos por Tienda')
ax.set_xticks(ind)
ax.set_xticklabels(stores)
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# En este paso, debes calcular el costo de envío promedio para cada tienda. El objetivo es comprender cuánto se gasta, en promedio, en el envío de cada tienda. Sabiendo que el cliente paga el envío.

# %%
costo_envio1 = tienda1_df['Costo de envío'].mean()
print(f"la Tienda 1, tiene un costo de envio de: {costo_envio1:.2f}")
# Out:
# la Tienda 1, tiene un costo de envio de: 26018.61

# %%
costo_envio2 = tienda2['Costo de envío'].mean()
print(f"la Tienda 2, tiene un costo de envio de: {costo_envio2:.2f}")
# Out:
# la Tienda 2, tiene un costo de envio de: 25216.24

# %%
costo_envio3 = tienda3['Costo de envío'].mean()
print(f"la Tienda 3, tiene un costo de envio de: {costo_envio3:.2f}")
# Out:
# la Tienda 3, tiene un costo de envio de: 24805.68

# %%
costo_envio4 = tienda4['Costo de envío'].mean()
print(f"la Tienda 4, tiene un costo de envio de: {costo_envio4:.2f}")
# Out:
# la Tienda 4, tiene un costo de envio de: 23459.46

# %% [markdown]
# #Visualización gráfica

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df_costos = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Costo Promedio de Envío': [costo_envio1, costo_envio2, costo_envio3, costo_envio4]
})

plt.figure(figsize=(12, 5))

stores = df_costos['Tienda']
costs = df_costos['Costo Promedio de Envío']
x_positions = np.arange(len(stores))
colors = ['skyblue', 'lightcoral', 'lightgreen', 'gold']


plt.bar(x_positions, costs, color=colors, alpha=0.7, label='Costo Promedio de Envío')


plt.plot(x_positions, costs, color='red', linestyle='-', marker='o', markersize=8, linewidth=2, label='Tendencia de Costo')


for i, cost in enumerate(costs):
    plt.text(x_positions[i], cost, f'{cost:.2f}', ha='center', va='bottom', fontsize=10, color='black')

plt.xticks(x_positions, stores)
plt.xlabel('Tiendas', fontsize=12)
plt.ylabel('Costo Promedio de Envío', fontsize=12)
plt.title('Costo Promedio de Envío por Tienda (Columnas y Línea)', fontsize=14)
plt.legend(title='Elemento', loc='upper right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()
